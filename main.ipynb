# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

df = pd.read_csv('vgsales_8.csv')
df
# Out:
#       Rank                                Name Platform    Year       Genre
# 0     9424                      Winning Post 5      PS2  2001.0      Sports  \
# 1    15694                    Prince of Stride      PSV  2015.0   Adventure
# 2    15166         Cities in Motion Collection       PC  2011.0  Simulation
# 3    12177                 Winning Post 7 2010      PS3  2010.0      Sports
# 4     9874  Ed, Edd n Eddy: The Mis-Edventures      GBA  2005.0    Platform
# ..     ...                                 ...      ...     ...         ...
# 548  12799                        Space Chimps       DS  2008.0    Platform
# 549  14424          Codename: Panzers Cold War       PC  2009.0    Strategy
# 550   7549                    MLB 10: The Show      PSP  2010.0      Sports
# 551   2207   The Witcher 2: Assassins of Kings     X360  2012.0      Action
# 552  15733                Super Speed Machines       DS  2009.0      Racing
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          553 non-null    int64
#  1   Name          553 non-null    object
#  2   Platform      553 non-null    object
#  3   Year          549 non-null    float64
#  4   Genre         553 non-null    object
#  5   Publisher     551 non-null    object
#  6   NA_Sales      553 non-null    float64
#  7   EU_Sales      553 non-null    float64
#  8   JP_Sales      553 non-null    float64
#  9   Other_Sales   553 non-null    float64
#  10  Global_Sales  553 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 47.6+ KB

# %%
df.describe()
# Out:
#                Rank         Year    NA_Sales    EU_Sales    JP_Sales
# count    553.000000   549.000000  553.000000  553.000000  553.000000  \
# mean    8360.500904  2006.701275    0.252477    0.153562    0.077052
# std     4726.436002     5.697517    0.671768    0.436873    0.288861
# min       30.000000  1981.000000    0.000000    0.000000    0.000000
# 25%     4597.000000  2003.000000    0.000000    0.000000    0.000000
# 50%     8508.000000  2007.000000    0.070000    0.020000    0.000000
# 75%    12452.000000  2011.000000    0.230000    0.110000    0.040000
# max    16583.000000  2016.000000    9.030000    5.040000    3.810000
#
#        Other_Sales  Global_Sales
# count   553.000000    553.000000
# mean      0.046890      0.530434
# std       0.121542      1.316603
# min       0.000000      0.010000
# 25%       0.000000      0.060000
# 50%       0.010000      0.160000
# 75%       0.040000      0.420000
# max       1.320000     14.760000

# %%
df.shape
# Out:
# (553, 11)

# %%
dff = df.drop(columns=['Year'])
dff.head(10)
# Out:
#     Rank                                Name Platform         Genre
# 0   9424                      Winning Post 5      PS2        Sports  \
# 1  15694                    Prince of Stride      PSV     Adventure
# 2  15166         Cities in Motion Collection       PC    Simulation
# 3  12177                 Winning Post 7 2010      PS3        Sports
# 4   9874  Ed, Edd n Eddy: The Mis-Edventures      GBA      Platform
# 5    935                GoldenEye 007 (2010)      Wii        Action
# 6   2583                      Dragon's Dogma     X360  Role-Playing
# 7  10040                          DiRT Rally     XOne        Racing
# 8  15402                   Motocross Mania 3       XB        Racing
# 9  13761               Infamous: First Light      PS4        Action
#
#                      Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0                   Tecmo Koei      0.00      0.00      0.13         0.00  \
# ...

# %%
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            4
# Genre           0
# Publisher       2
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
dfz = df.replace({'Year' : np.nan}, '2023')
dfz.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       2
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
dfq = df
simple = SimpleImputer(strategy='mean', missing_values=np.nan)
simple = simple.fit(dfq[['Year']])
dfq['Year'] = simple.transform(dfq[['Year']])
dfq.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       2
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df.sort_values(by='Platform', ascending=False).tail(10)
# Out:
#       Rank                                      Name Platform         Year
# 235   8216       Yu-Gi-Oh! Zexal World Duel Carnival      3DS  2013.000000  \
# 34    5717                      Bust-A-Move Universe      3DS  2011.000000
# 133  12094         Moshi Monsters: Katsuma Unleashed      3DS  2013.000000
# 202   8509  Doctor Lautrec and the Forgotten Knights      3DS  2011.000000
# 504   9128                    Farming Simulator 2012      3DS  2012.000000
# 365   4884                LEGO The Lord of the Rings      3DS  2012.000000
# 375   4786                                Mouse Trap     2600  1981.000000
# 101   7371                           Ghostbusters II     2600  2006.701275
# 389   4896                             Bump 'n' Jump     2600  1982.000000
# 233   3046                        Adventures of Tron     2600  1981.000000
#
#          Genre                               Publisher  NA_Sales  EU_Sales
# ...

# %%
df.to_csv('df.csv')
dff.to_csv('dff.csv')
dfq.to_csv('dfq.csv')
dfz.to_csv('dfz.csv')
